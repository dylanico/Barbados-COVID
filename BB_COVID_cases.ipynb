# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("white")

# %%
df = pd.read_csv("owid-covid-data.csv")

# %%
Barbados_data = df[df["location"] == "Barbados"]

# %%
Barbados_data.head(n=10)
# Out:
#       iso_code      continent  location        date  total_cases  new_cases  \
# 14944      BRB  North America  Barbados  2020-03-17          2.0        2.0
# 14945      BRB  North America  Barbados  2020-03-18          2.0        0.0
# 14946      BRB  North America  Barbados  2020-03-19          5.0        3.0
# 14947      BRB  North America  Barbados  2020-03-20          5.0        0.0
# 14948      BRB  North America  Barbados  2020-03-21          6.0        1.0
# 14949      BRB  North America  Barbados  2020-03-22         14.0        8.0
# 14950      BRB  North America  Barbados  2020-03-23         17.0        3.0
# 14951      BRB  North America  Barbados  2020-03-24         18.0        1.0
# 14952      BRB  North America  Barbados  2020-03-25         18.0        0.0
# 14953      BRB  North America  Barbados  2020-03-26         18.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
bb_cases = sns.scatterplot(x=Barbados_data['date'], y = Barbados_data['total_cases'])
spacing = 250
visible = bb_cases.xaxis.get_ticklabels()[::spacing]
for label in bb_cases.xaxis.get_ticklabels():
    if label not in visible:
        label.set_visible(False)


plt.title("Graph showing Barbados' total COVID-19 cases since the beginning of the pandemic")
plt.show()

# %%
Barbados_data.shape
# Out:
# (808, 67)
